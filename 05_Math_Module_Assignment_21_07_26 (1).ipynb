# %% [markdown]
# ### Airthmetic operations

# %% [markdown]
# #### 1.Write a program to calculate the square root of a number using the math module.

# %%
import math as m
num = 25
print(f"The Sqare root of {num} is: ",m.sqrt(num))
# Out:
# The Sqare root of 25 is:  5.0

# %% [markdown]
# #### 2.Find the cube root of a given number using mathematical operations.

# %%
num = 50
print(f"The cube root of {num} is:",m.cbrt(num))
# Out:
# The cube root of 50 is: 3.6840314986403864

# %% [markdown]
# #### 3.Calculate the factorial of a number using math.factorial().

# %%
num = 4
print(f"The factorial of {num} is:",m.factorial(num))
# Out:
# The factorial of 4 is: 24

# %% [markdown]
# #### 4.Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().

# %%
a,b = 6,4
print(f'The GCD of {a,b} is: ',m.gcd(a,b))
# Out:
# The GCD of (6, 4) is:  2

# %% [markdown]
# #### 5.Find the LCM of two numbers using math.lcm().

# %%
a,b = 4,3
print(f'The LCM of {a,b} is: ',m.lcm(a,b))
# Out:
# The LCM of (4, 3) is:  12

# %% [markdown]
# #### 6.Calculate the value of 5 raised to the power of 8 using math.pow().

# %%
print('The Value is:',m.pow(5,8))
# Out:
# The Value is: 390625.0

# %% [markdown]
# #### 7.Find the absolute value of a negative decimal number using math.fabs().

# %%
num = -9.5
print(f'The Absolute value is:',m.fabs(num))
# Out:
# The Absolute value is: 9.5

# %% [markdown]
# #### 8.Round a floating-point number up using math.ceil().

# %%
num = 8.9
print(f"The Round value of {num} is:",m.ceil(num))
# Out:
# The Round value of 8.9 is: 9

# %% [markdown]
# #### 9.Round a floating-point number down using math.floor().

# %%
num = 5.6
print(f'The Round value  of {num} is:',m.floor(num))
# Out:
# The Round value  of 5.6 is: 5

# %% [markdown]
# #### 10.Round a floating-point number to the nearest integer using round().

# %%
num = 4.3
print(f'The Round value of {num} is:',round(num))
# Out:
# The Round value of 4.3 is: 4

# %% [markdown]
# #### 11.Find the remainder of two numbers using math.fmod().

# %%
a,b = 4,6
print(f"The Remainder of {num} is: ",m.fmod(a,b))
# Out:
# The Remainder of 4.3 is:  4.0

# %% [markdown]
# #### 12.Find the quotient and remainder using divmod().

# %%
a,b = 2,4
print(f"The Quotient and remainder are:",divmod(a,b))
# Out:
# The Quotient and remainder are: (0, 2)

# %% [markdown]
# #### 13.Calculate the sine, cosine, and tangent of 45 degrees.

# %%
angle = 45
print(f'The value of sine{angle} is:',m.sin(angle))
print(f'The value of cosine{angle} is:',m.cos(angle))
print(f'The value of tangent{angle} is:',m.tan(angle))
# Out:
# The value of sine45 is: 0.8509035245341184
# The value of cosine45 is: 0.5253219888177297
# The value of tangent45 is: 1.6197751905438615

# %% [markdown]
# #### 14.Convert an angle from degrees to radians.

# %%
angle = 45
print(f'The radian of {angle} is:',m.radians(angle))
# Out:
# The radian of 45 is: 0.7853981633974483

# %% [markdown]
# #### 15.Convert an angle from radians to degrees.

# %%
angle = 45
print(f'The degree of an {45} is:',m.degrees(angle))
# Out:
# The degree of an 45 is: 2578.3100780887044

# %% [markdown]
# #### 16.Find the logarithm (base 10) of a number using math.log10().

# %%
num = 5
print(f'The logarithm (base 10) of a {num} is:',m.log10(num))
# Out:
# The logarithm (base 10) of a 5 is: 0.6989700043360189

# %% [markdown]
# #### 17.Find the natural logarithm of a number using math.log().

# %%
num = 5
print(f"The logarithm of a {num}",m.log(num))
# Out:
# The logarithm of a 5 1.6094379124341003

# %% [markdown]
# #### 18.Calculate e raised to the power of x using math.exp().

# %%
result = m.exp(5)
print(result)
# Out:
# 148.4131591025766

# %% [markdown]
# #### 19.Find the value of π (pi) and Euler's number (e) from the math module.

# %%
print("The pi value and Eluer's number are:",m.pi,m.e)
# Out:
# The pi value and Eluer's number are: 3.141592653589793 2.718281828459045

# %% [markdown]
# #### 20.Find the distance between two points using math.dist().

# %%
a = (1,2)
b = (4,6)
print(f"The distance between {a} and {b} is:",m.dist(a,b))
# Out:
# The distance between (1, 2) and (4, 6) is: 5.0

# %% [markdown]
# #### 21.Calculate the hypotenuse of a right triangle using math.hypot()

# %%
a = 4
b = 3
print(f"Teh hypotenuse of right angle triangle is:",m.hypot(a,b))
# Out:
# Teh hypotenuse of right angle triangle is: 5.0

# %% [markdown]
# #### 22.Find the combination (nCr) using math.comb().

# %%
result = m.comb(5, 2)
print(result)
# Out:
# 10

# %% [markdown]
# #### 23.Find the permutation (nPr) using math.perm().

# %%
result = m.perm(6,2)
print(result)
# Out:
# 30

# %% [markdown]
# #### 24.Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().

# %%
num = 4
if m.isfinite(num):
  print("The number is finite")
elif m.isinf(num):
  print("The number is infinite")
elif m.isnan(num):
  print("The number is nan")
# Out:
# The number is finite

# %% [markdown]
# #### 25.Find the product of all numbers in a list using math.prod().

# %%
num = [1,2,3,4]
print(f'The product of numbers of :',m.prod(num))
# Out:
# The product of numbers of : 24

# %% [markdown]
# #### 26.Find the sum of square roots of all numbers in a list.

# %%
numbers = [1, 4, 9, 16, 25]
result = sum(m.sqrt(num) for num in numbers)
print(result)
# Out:
# 15.0

# %% [markdown]
# #### 27.Find the largest integer less than or equal to the square root of a given number.

# %%
num = 20
result = m.isqrt(num)
print(result)
# Out:
# 4

# %% [markdown]
# #### 28.Calculate compound interest using math.pow()

# %%
import math

p = 1000
r = 10 / 100
t = 2

amount = p * math.pow(1 + r, t)

print(amount)
# Out:
# 1210.0000000000002

# %% [markdown]
# #### 30.Find the area and circumference of a circle using math.pi.

# %%
import math as m
radius = 5
area = math.pi * radius ** 2
circumference = 2 * m.pi * radius
print("Area:", area)
print("Circumference:", circumference)
# Out:
# Area: 78.53981633974483
# Circumference: 31.41592653589793

# %% [markdown]
# #### 30.Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

# %%
import math

print("Scientific Calculator")
print("1. Square Root")
print("2. Factorial")
print("3. Logarithm")
print("4. Power")
print("5. Sine")
print("6. Cosine")
print("7. Tangent")
print("8. GCD")
print("9. LCM")

choice = int(input("Enter your choice: "))

if choice == 1:
    num = float(input("Enter a number: "))
    print("Square Root =", math.sqrt(num))

elif choice == 2:
    num = int(input("Enter a number: "))
    print("Factorial =", math.factorial(num))

elif choice == 3:
    num = float(input("Enter a number: "))
    print("Log10 =", math.log10(num))

elif choice == 4:
    base = float(input("Enter base: "))
    exponent = float(input("Enter exponent: "))
    print("Power =", math.pow(base, exponent))

elif choice == 5:
    angle = float(input("Enter angle in degrees: "))
    print("Sin =", math.sin(math.radians(angle)))

elif choice == 6:
    angle = float(input("Enter angle in degrees: "))
    print("Cos =", math.cos(math.radians(angle)))

elif choice == 7:
    angle = float(input("Enter angle in degrees: "))
    print("Tan =", math.tan(math.radians(angle)))

elif choice == 8:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("GCD =", math.gcd(a, b))

elif choice == 9:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("LCM =", math.lcm(a, b))

else:
    print("Invalid Choice")
# Out:
# Scientific Calculator
# 1. Square Root
# 2. Factorial
# 3. Logarithm
# 4. Power
# 5. Sine
# 6. Cosine
# 7. Tangent
# 8. GCD
# 9. LCM
# Enter your choice: 3
# Enter a number: 3
# Log10 = 0.47712125471966244

# %% [markdown]
# ## Python Operators

# %% [markdown]
# ### Arithmetic Operators

# %% [markdown]
# #### 1.Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.

# %%
a, b = 2,3
print("The Addition of two  numbers are",a + b)
print("The Subtraction of two  numbers are",a - b)
print("The Multiplication of two  numbers are",a * b)
print("The Division of two  numbers are",a / b)
print("The Floor Division of two  numbers are",a // b)
print("The Modulus of two  numbers are",a % b)
print("The Exponentiation of two  numbers are",a ** b)
# Out:
# The Addition of two  numbers are 5
# The Subtraction of two  numbers are -1
# The Multiplication of two  numbers are 6
# The Division of two  numbers are 0.6666666666666666
# The Floor Division of two  numbers are 0
# The Modulus of two  numbers are 2
# The Exponentiation of two  numbers are 8

# %% [markdown]
# #### 2.Swap two numbers without using a third variable.

# %%
a,b = 2,3
a,b = b,a
print(a,b)
# Out:
# 3 2

# %% [markdown]
# #### 3.Find whether a number is even or odd using the modulus operator.

# %%
num = 3
if num % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# Odd

# %% [markdown]
# #### 4.Reverse a three-digit number using arithmetic operators.

# %%
num = 123
hundreds = num // 100
tens = (num // 10) % 10
ones = num % 10
reversed_num = ones * 100 + tens * 10 + hundreds
print(reversed_num)   # 321
# Out:
# 321

# %% [markdown]
# #### 5.Find the last digit and first digit of a given number.

# %%
num = 123
last_digit = num % 10
while num >= 10:
    num = num // 10
first_digit = num
print("First Digit:", first_digit)
print("Last Digit:", last_digit)
# Out:
# First Digit: 1
# Last Digit: 3

# %% [markdown]
# ### Assignment Operators

# %% [markdown]
# #### 6.Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.

# %%
num = 10
print("Initial Value:", num)
num += 5
print("After += :", num)
num -= 3
print("After -= :", num)
num *= 2
print("After *= :", num)
num /= 4
print("After /= :", num)
num //= 2
print("After //= :", num)
num %= 3
print("After %= :", num)
num **= 2
print("After **= :", num)
# Out:
# Initial Value: 10
# After += : 15
# After -= : 12
# After *= : 24
# After /= : 6.0
# After //= : 3.0
# After %= : 0.0
# After **= : 0.0

# %% [markdown]
# #### 7.Update a bank account balance using compound assignment operators.

# %%
balance = 5000
print("Initial Balance:", balance)
balance += 2000
print("After Deposit:", balance)
balance -= 1500
print("After Withdrawal:", balance)
balance *= 2
print("After *= :", balance)
balance /= 4
print("After /= :", balance)
balance //= 2
print("After //= :", balance)
balance %= 1000
print("After %= :", balance)
balance **= 2
print("After **= :", balance)
# Out:
# Initial Balance: 5000
# After Deposit: 7000
# After Withdrawal: 5500
# After *= : 11000
# After /= : 2750.0
# After //= : 1375.0
# After %= : 375.0
# After **= : 140625.0

# %% [markdown]
# #### 8.Calculate the total marks using += inside a loop.

# %%
marks = [10, 20, 30, 50]
total = 0
for mark in marks:
    total += mark
print("Total Marks:", total)
# Out:
# Total Marks: 110

# %% [markdown]
# ### Comparison Operators

# %% [markdown]
# #### 9.Compare two numbers and print the larger number.

# %%
a, b = 2, 3
if a > b:
  print(a)
else:
  print(b)
# Out:
# 3

# %% [markdown]
# #### 10.Check whether three numbers are equal.

# %%
a,b,c = 2,2,2
if a == b and b == c and a == c:
  print("All numbers are Equal")
else:
  print("All numbers are not Equal")
# Out:
# All numbers are Equal

# %% [markdown]
# #### 11.Find the largest among three numbers using comparison operators.

# %%
a,b,c = 2,3,6
if a>b and a>c:
  print(a)
elif b>c and b>a:
  print(b)
else:
  print(c)
# Out:
# 6

# %% [markdown]
# #### 12.Check whether a student is eligible to vote based on age.

# %%
age = 13
if age >= 18:
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Not Eligible

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# #### 13.Check if a person is eligible for a loan (age > 21 AND salary > 30000).

# %%
age = 16
salary = 40000
if age > 21:
  if salary > 30000:
    print("Eligible for a loan")
  else:
    print("Insufficent Balance")
else:
  print("You are not old enough to take loan")
# Out:
# You are not old enough to take loan

# %% [markdown]
# #### 14.Check if a number lies between 10 and 100 using logical operators.

# %%
num = 55
if num >= 10 and num <= 100:
    print("The number lies between 10 and 100.")
else:
    print("The number does not lie between 10 and 100.")
# Out:
# The number lies between 10 and 100.

# %% [markdown]
# #### 15.Validate username and password using logical operators.

# %%
user_name = input("Enter the user name: ")
password = input("Enter the paswword: ")
if user_name.lower() == 'naga':
  if password == 'Naga@23':
    print("Credentials Matched")
  else:
    print("Credentials Not Matched")
else:
  print("Invalid User Name.")
# Out:
# Enter the user name: Naga
# Enter the paswword: Naga@23
# Credentials Matched

# %% [markdown]
# #### 16.Determine whether a year is a leap year using logical conditions.

# %%
year = 2024
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %% [markdown]
# ### Bitwise Operators

# %% [markdown]
# #### 17.Find the bitwise AND, OR, XOR of two numbers.

# %%
num1 = 10
num2 = 6
print("Bitwise AND:", num1 & num2)
print("Bitwise OR:", num1 | num2)
print("Bitwise XOR:", num1 ^ num2)
# Out:
# Bitwise AND: 2
# Bitwise OR: 14
# Bitwise XOR: 12

# %% [markdown]
# #### 18.Perform left shift and right shift operations.

# %%
num = 10
print("Left Shift by 1:", num << 1)
print("Right Shift by 1:", num >> 1)
# Out:
# Left Shift by 1: 20
# Right Shift by 1: 5

# %% [markdown]
# #### 19.Check whether a number is even using a bitwise operator.

# %%
num = 8
if num & 1 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# #### 20.Swap two numbers using the XOR operator.

# %%
a,b = 2,3
a = a ^ b
b = b ^ a
a = a ^ b
print(a)
print(b)
# Out:
# 3
# 2

# %% [markdown]
# #### 21.Count how many bits are set to 1 in a number using bitwise operations.

# %%
num = int(input("Enter a number: "))
count = 0
while num > 0:
    if num & 1:
        count += 1
    num = num >> 1
print("Number of set bits:", count)
# Out:
# Enter a number: 1
# Number of set bits: 1

# %% [markdown]
# #### 22.Demonstrate the difference between is and ==.

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a
print("a == b :", a == b)
print("a is b :", a is b)
print("a == c :", a == c)
print("a is c :", a is c)
# Out:
# a == b : True
# a is b : False
# a == c : True
# a is c : True

# %% [markdown]
# #### 23.Check whether two variables refer to the same list object

# %%
list1 = [10, 20, 30]
list2 = list1
if list1 is list2:
    print("Both variables refer to the same object.")
else:
    print("Different objects.")
# Out:
# Both variables refer to the same object.

# %% [markdown]
# #### 24.Show the behavior of is not with integers and lists.

# %%
a = 100
b = 100
print(a is not b)
x = [1, 2]
y = [1, 2]
print(x is not y)
# Out:
# False
# True

# %% [markdown]
# #### 25.Check whether a character exists in a string.

# %%
string = 'Hello'
if 'h' in string.lower():
  print(f"h is in {string}")
else:
  print(f"h is not in {string}")
# Out:
# h is in Hello

# %% [markdown]
#  ####  26.Check whether a number exists in a list.

# %%
lst = [1,2,3]
choice = int(input("Enter the number:"))
if choice in lst:
  print(f"{choice} is  present in the list")
else:
  print(f"{choice} is not present in the list")
# Out:
# Enter the number:4
# 4 is not present in the list

# %% [markdown]
# #### 27.Count how many vowels in a string belong to a predefined vowel list using in.

# %%
text = input("Enter a string: ")
vowels = "aeiouAEIOU"
count = 0
for ch in text:
    if ch in vowels:
        count += 1
print("Total vowels:", count)
# Out:
# Enter a string: hello
# Total vowels: 2

# %% [markdown]
# #### 28.Build a simple calculator using arithmetic and comparison operators.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("\n1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice (1-4): "))

match choice:
    case 1:
        print("Addition:", num1 + num2)

    case 2:
        print("Subtraction:", num1 - num2)

    case 3:
        print("Multiplication:", num1 * num2)

    case 4:
        if num2 != 0:
            print("Division:", num1 / num2)
        else:
            print("Division by zero is not allowed.")

    case _:
        print("Invalid Choice")

# Comparison Operators
print("\nComparison Results")
print("Equal:", num1 == num2)
print("Greater:", num1 > num2)
print("Less:", num1 < num2)
# Out:
# Enter first number: 4
# Enter second number: 3
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1-4): 1
# Addition: 7.0
#
# Comparison Results
# Equal: False
# Greater: True
# Less: False

# %% [markdown]
# #### 29.Create a grading system using comparison and logical operators.

# %%
mark = int(input("Enter the marks:"))
if mark >= 90 and mark <= 100:
  print("Grade A")
elif mark >= 80 and mark <= 90:
  print("Grade B")
elif mark >= 70 and mark <= 80:
  print("Grade C")
elif mark >= 60 and mark <= 70:
  print("Grade D")
elif mark >= 35 and mark <= 60:
  print("Grade E")
else:
  print("Fail")
# Out:
# Enter the marks:45
# Grade E

# %% [markdown]
# #### 30.Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

# %%
result = 0

while True:
    print("\n========== MENU ==========")
    print("1. Arithmetic Operations")
    print("2. Comparison Operations")
    print("3. Logical Operations")
    print("4. Assignment Operations")
    print("5. Membership Operations")
    print("6. Identity Operations")
    print("7. Bitwise Operations")
    print("8. Exit")

    choice = int(input("Enter your choice: "))

    match choice:

        case 1:
            a = int(input("Enter first number: "))
            b = int(input("Enter second number: "))

            print("Addition:", a + b)
            print("Subtraction:", a - b)
            print("Multiplication:", a * b)

            if b != 0:
                print("Division:", a / b)
            else:
                print("Division by zero is not allowed.")

        case 2:
            a = int(input("Enter first number: "))
            b = int(input("Enter second number: "))

            print("a == b :", a == b)
            print("a != b :", a != b)
            print("a > b  :", a > b)
            print("a < b  :", a < b)
            print("a >= b :", a >= b)
            print("a <= b :", a <= b)

        case 3:
            a = int(input("Enter first number: "))
            b = int(input("Enter second number: "))

            print("Both Positive :", a > 0 and b > 0)
            print("At least One Positive :", a > 0 or b > 0)
            print("Not Equal :", not (a == b))

        case 4:
            x = int(input("Enter a number: "))

            print("Original Value:", x)

            x += 5
            print("After += 5 :", x)

            x -= 2
            print("After -= 2 :", x)

            x *= 3
            print("After *= 3 :", x)

            x //= 2
            print("After //= 2 :", x)

        case 5:
            numbers = [10, 20, 30, 40, 50]
            n = int(input("Enter a number: "))

            if n in numbers:
                print("Number is present.")
            else:
                print("Number is not present.")

            print("Using 'not in':", n not in numbers)

        case 6:
            list1 = [1, 2, 3]
            list2 = list1
            list3 = [1, 2, 3]

            print("list1 is list2 :", list1 is list2)
            print("list1 is list3 :", list1 is list3)
            print("list1 == list3 :", list1 == list3)
            print("list1 is not list3 :", list1 is not list3)

        case 7:
            num = int(input("Enter a number: "))

            print("Binary:", bin(num))
            print("Even:", (num & 1) == 0)
            print("Left Shift by 1 :", num << 1)
            print("Right Shift by 1:", num >> 1)

            count = 0
            temp = num

            while temp > 0:
                count += temp & 1
                temp >>= 1

            print("Set Bits:", count)

        case 8:
            print("Thank You!")
            break

        case _:
            print("Invalid Choice. Please try again.")
# Out:
# ========== MENU ==========
# 1. Arithmetic Operations
# 2. Comparison Operations
# 3. Logical Operations
# 4. Assignment Operations
# 5. Membership Operations
# 6. Identity Operations
# 7. Bitwise Operations
# 8. Exit
