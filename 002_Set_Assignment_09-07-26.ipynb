# %%
bank = [
    [ # Bank 1
        [ # Branch 1 of Bank 1
            ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000]
        ],
        [ # Branch 2 of Bank 1
            ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]
        ]
    ],
    [ # Bank 2
        [ # Branch 1 of Bank 2
            ["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]
        ],
        [ # Branch 2 of Bank 2
            ["C204", "Priya", "Savings", 45000],
            ["C205", "Amit", "Current", 185000],
            ["C206", "Divya", "Loan", 650000]
        ]
    ],
    [ # Bank 3
        [ # Branch 1 of Bank 3
            ["C301", "Nikhil", "Savings", 78000],
            ["C302", "Kavya", "Current", 240000],
            ["C303", "Suresh", "Loan", 1000000]
        ],
        [ # Branch 2 of Bank 3
            ["C304", "Neha", "Savings", 135000],
            ["C305", "Rohan", "Current", 410000],
            ["C306", "Asha", "Loan", 550000]
        ]
    ]
]
print(bank)
# Out:
# [[[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]], [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]], [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]]

# %% [markdown]
# ####1.Prints Rahul's Complete Record

# %%
print("Rahul's Complete Record: ",bank[0][0][0])
# Out:
# Rahul's Complete Record:  ['C101', 'Rahul', 'Savings', 85000]

# %% [markdown]
# ####2.Print Anitha's Account Type

# %%
print("Anitha's Account Type: ",bank[0][0][1][2])
# Out:
# Anitha's Account Type:  Current

# %% [markdown]
# ####3.Print Kiran's Loan Amount

# %%
print("Kiran's Load Amount: ",bank[0][0][2][3])
# Out:
# Kiran's Load Amount:  500000

# %% [markdown]
# ####4.Print Sneha's Customer ID

# %%
print("Sneha's Customer ID: ",bank[0][1][0][0])
# Out:
# Sneha's Customer ID:  C104

# %% [markdown]
# ####5.Print Vikram's Balanace

# %%
print("Virkram's Balance : ",bank[0][1][1][3])
# Out:
# Virkram's Balance :  275000

# %% [markdown]
# ####6.Print Meena's complete record.

# %%
print("Meena's Complete Record: ",bank[0][1][2])
# Out:
# Meena's Complete Record:  ['C106', 'Meena', 'Loan', 750000]

# %% [markdown]
# ####7.Print Arjun's customer ID.

# %%
print("Arjun's Customer ID: ",bank[1][0][0][0])
# Out:
# Arjun's Customer ID:  C201

# %% [markdown]
# ####8.Print Pooja's name.

# %%
print("Pooja's Name: ",bank[1][0][1][1])
# Out:
# Pooja's Name:  Pooja

# %% [markdown]
# ####9.Print Ramesh's account type.

# %%
print("Ramesh's Account Type: ",bank[1][0][2][3])
# Out:
# Ramesh's Account Type:  900000

# %% [markdown]
# ####10. Print Priya's balance.

# %%
print("Priya's Balance: ",bank[1][1][1][3])
# Out:
# Priya's Balance:  185000

# %% [markdown]
# ####11. Print Amit's account type.

# %%
print("Amit's Account Type: ",bank[1][1][1][2])
# Out:
# Amit's Account Type:  Current

# %% [markdown]
# #### 12.Print Divya's customer ID.

# %%
print("Divya's Customer ID: ",bank[1][1][2][0])
# Out:
# Divya's Customer ID:  C206

# %% [markdown]
# ####13. Print Nikhil's account type.

# %%
print("Nikhil's Account type: ",bank[2][0][0][2])
# Out:
# Nikhil's Account type:  Savings

# %% [markdown]
# #### 14.Print Kavya's balance.

# %%
print("Kavya's Balance: ",bank[2][0][1][3])
# Out:
# Kavya's Balance:  240000

# %% [markdown]
# #### 15.Print Suresh's loan amount.

# %%
print("Suresh's Loan Amount: ",bank[2][0][2][3])
# Out:
# Suresh's Loan Amount:  1000000

# %% [markdown]
# #### 16.Print Neha's name.

# %%
print("Neha's Name: ",bank[2][1][0][1])
# Out:
# Neha's Name:  Neha

# %% [markdown]
# #### 17.Print Rohan's complete record.

# %%
print("Rohan's Complete Record: ",bank[2][1][1])
# Out:
# Rohan's Complete Record:  ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# #### 18.Print Asha's account type.

# %%
print("Asha's Account Type: ",bank[2][1][2][2])
# Out:
# Asha's Account Type:  Loan

# %% [markdown]
# #### 19.Print all customers in Bank 1, Branch 1.

# %%
print("All Customers in Bank 1, Branch 1 : ",bank[0][0])
# Out:
# All Customers in Bank 1, Branch 1 :  [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %% [markdown]
# #### 20.Print all customers in Bank 1, Branch 2.

# %%
print("All Customers in Bank 1, Branch 2: ",bank[0][1])
# Out:
# All Customers in Bank 1, Branch 2:  [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %% [markdown]
# #### 21.Print all customers in Bank 2, Branch 1.

# %%
print("All Customers in Bank 2, Branch 1:",bank[1][0])
# Out:
# All Customers in Bank 2, Branch 1: [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %% [markdown]
# #### 22.Print all customers in Bank 2, Branch 2.

# %%
print("All Customers in Bank 2, Branch 2: ",bank[1][1])
# Out:
# All Customers in Bank 2, Branch 2:  [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %% [markdown]
# #### 23.Print all customers in Bank 3, Branch 1.

# %%
print("All Customers in Bank 3, Branch 1:",bank[2][0])
# Out:
# All Customers in Bank 3, Branch 1: [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %% [markdown]
# #### 24.Print all customers in Bank 3, Branch 2.

# %%
print("All Cutsomers from Bank 3, branch 2: ",bank[2][1])
# Out:
# All Cutsomers from Bank 3, branch 2:  [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %% [markdown]
# #### 25.Print all branches of Bank 1.

# %%
print("All branches of Bank 1:",bank[0])
# Out:
# All branches of Bank 1: [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %% [markdown]
# #### 26.Print all branches of Bank 2.

# %%
print("All Branches From Bank 2: ", bank[1])
# Out:
# All Branches From Bank 2:  [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %% [markdown]
# #### 27.Print all branches of Bank 3.

# %%
print("All Branches From Bank 3:",bank[2])
# Out:
# All Branches From Bank 3: [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %% [markdown]
# #### 28.Print the first customer from every bank's first branch.

# %%
print("First customer from Bank 1, Branch 1:", bank[0][0][0])
print("First customer from Bank 2, Branch 1:", bank[1][0][0])
print("First customer from Bank 3, Branch 1:", bank[2][0][0])
# Out:
# First customer from Bank 1, Branch 1: ['C101', 'Rahul', 'Savings', 85000]
# First customer from Bank 2, Branch 1: ['C201', 'Arjun', 'Savings', 120000]
# First customer from Bank 3, Branch 1: ['C301', 'Nikhil', 'Savings', 78000]

# %% [markdown]
# #### 29.Print the second customer from every bank's second branch.

# %%
print("Second customer from Bank 1, Branch 2:", bank[0][1][1])
print("Second customer from Bank 2, Branch 2:", bank[1][1][1])
print("Second customer from Bank 3, Branch 2:", bank[2][1][1])
# Out:
# Second customer from Bank 1, Branch 2: ['C105', 'Vikram', 'Current', 275000]
# Second customer from Bank 2, Branch 2: ['C205', 'Amit', 'Current', 185000]
# Second customer from Bank 3, Branch 2: ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# #### 30.Print the loan amount of the last customer in Bank 3, Branch 2.

# %%
print("The Loan Amount of last customer in bank 3, branch 2: ",bank[2][1][2][3])
# Out:
# The Loan Amount of last customer in bank 3, branch 2:  550000
