# %% [markdown]
# # Python String Indexing Assignment

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text)

# %% [markdown]
# ### 1. Print "Edukron"

# %%
print(text[0:7])

# %% [markdown]
# ### 2. Print "Data" (first occurrence)

# %%
print(text[8:12])

# %% [markdown]
# ### 3. Print "Science"

# %%
print(text[13:20])

# %% [markdown]
# ### 4. Print "and"

# %%
print(text[21:24])

# %% [markdown]
# ### 5. Print "Data Engineering"

# %%
print(text[25:41])

# %% [markdown]
# ### 6. Print "Engineering"

# %%
print(text[30:41])

# %% [markdown]
# ### 7. Print "Batch"

# %%
print(text[42:47])

# %% [markdown]
# ### 8. Print "2026"

# %%
print(text[48:52])  # or text[-4:]

# %% [markdown]
# ### 9. Print "Science and Data"

# %%
print(text[13:29])

# %% [markdown]
# ### 10. Print "Data Science and Data Engineering Batch"

# %%
print(text[8:47])
